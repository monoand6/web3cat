# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], "../.."))

# %%
from datetime import datetime
from web3cat.data import ERC20Data

# %%
dates = [datetime(2021, 6, 1), datetime(2021, 7, 1), datetime(2021, 8, 1), datetime(2021, 9, 1)]
addresses = ["0x5d3a536E4D6DbD6114cc1Ead35777bAB948E3643", "0xbEbc44782C7dB0a1A60Cb6fe97d0b483032FF1C7"]
erc20_data = ERC20Data("Dai", addresses, min(dates), max(dates))

# %%
# All erc20 transfers for addresses
erc20_data.transfers
# Out:
# shape: (54606, 8)
# ┌─────────────┬─────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┐
# │ timestamp   ┆ date        ┆ block_numb ┆ transactio ┆ log ┆ from       ┆ to         ┆ value      │
# │ ---         ┆ ---         ┆ er         ┆ n_hash     ┆ _in ┆ ---        ┆ ---        ┆ ---        │
# │ u64         ┆ datetime[μs ┆ ---        ┆ ---        ┆ dex ┆ str        ┆ str        ┆ f64        │
# │             ┆ ]           ┆ u64        ┆ str        ┆ --- ┆            ┆            ┆            │
# │             ┆             ┆            ┆            ┆ u64 ┆            ┆            ┆            │
# ╞═════════════╪═════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╡
# │ 1622491566  ┆ 2021-06-01  ┆ 12544172   ┆ 0x04cc9695 ┆ 234 ┆ 0x5d3a536e ┆ 0xebfb47a7 ┆ 305478.247 │
# │             ┆ 00:06:06    ┆            ┆ 7f36876da4 ┆     ┆ 4d6dbd6114 ┆ ad0fd6e573 ┆ 364        │
# │             ┆             ┆            ┆ f92d047e40 ┆     ┆ cc1ead3577 ┆ 23c8a42b2e ┆            │
# │             ┆             ┆            ┆ 8c3a7ee1f1 ┆     ┆ 7bab948e36 ┆ 5a6a4f68fc ┆            │
# │             ┆             ┆            ┆ e77b...    ┆     ┆ 43         ┆ 1a         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1622491592  ┆ 2021-06-01  ┆ 12544174   ┆ 0x091ef73c ┆ 103 ┆ 0x3c8caee4 ┆ 0xbebc4478 ┆ 16896.3814 │
# │             ┆ 00:06:32    ┆            ┆ 72fa515a61 ┆     ┆ e09296800f ┆ 2c7db0a1a6 ┆ 47         │
# │             ┆             ┆            ┆ adc7743337 ┆     ┆ 8d29a68fa3 ┆ 0cb6fe97d0 ┆            │
# │             ┆             ┆            ┆ a66aecf712 ┆     ┆ 837e2dae49 ┆ b483032ff1 ┆            │
# │             ┆             ┆            ┆ 8eb7...    ┆     ┆ 40         ┆ c7         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1622491697  ┆ 2021-06-01  ┆ 12544182   ┆ 0x73cb909c ┆ 238 ┆ 0xbebc4478 ┆ 0x56680fde ┆ 28483.6661 │
# │             ┆ 00:08:17    ┆            ┆ 92f587191c ┆     ┆ 2c7db0a1a6 ┆ bdd3e31f79 ┆ 72         │
# │             ┆             ┆            ┆ 2ca7ec8b46 ┆     ┆ 0cb6fe97d0 ┆ 938fa1222b ┆            │
# │             ┆             ┆            ┆ ce01178324 ┆     ┆ b483032ff1 ┆ fea4706a07 ┆            │
# │             ┆             ┆            ┆ e0c0...    ┆     ┆ c7         ┆ 58         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1622491776  ┆ 2021-06-01  ┆ 12544188   ┆ 0xecde0e1e ┆ 156 ┆ 0x11fbfe3a ┆ 0xbebc4478 ┆ 60000.0    │
# │             ┆ 00:09:36    ┆            ┆ 23330b1901 ┆     ┆ 6c183dcd6f ┆ 2c7db0a1a6 ┆            │
# │             ┆             ┆            ┆ 297f538072 ┆     ┆ d9baa42fe3 ┆ 0cb6fe97d0 ┆            │
# │             ┆             ┆            ┆ e7c3ac3807 ┆     ┆ 9206174a6c ┆ b483032ff1 ┆            │
# │             ┆             ┆            ┆ dd8b...    ┆     ┆ 00         ┆ c7         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...         ┆ ...         ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630437784  ┆ 2021-08-31  ┆ 13135177   ┆ 0x7c00b125 ┆ 59  ┆ 0x1bd435f3 ┆ 0xbebc4478 ┆ 694141.384 │
# │             ┆ 23:23:04    ┆            ┆ 749f228cd8 ┆     ┆ c054b6e901 ┆ 2c7db0a1a6 ┆ 844        │
# │             ┆             ┆            ┆ f6cc9c95aa ┆     ┆ b7b108a0ab ┆ 0cb6fe97d0 ┆            │
# │             ┆             ┆            ┆ 8b28385510 ┆     ┆ 7617c80867 ┆ b483032ff1 ┆            │
# │             ┆             ┆            ┆ bd32...    ┆     ┆ 7b         ┆ c7         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630437903  ┆ 2021-08-31  ┆ 13135186   ┆ 0x6de794a5 ┆ 160 ┆ 0x890f4e34 ┆ 0xbebc4478 ┆ 147817.025 │
# │             ┆ 23:25:03    ┆            ┆ ac8efb8913 ┆     ┆ 5b1daed036 ┆ 2c7db0a1a6 ┆ 5          │
# │             ┆             ┆            ┆ f7ef04c83d ┆     ┆ 7a877a1612 ┆ 0cb6fe97d0 ┆            │
# │             ┆             ┆            ┆ 80f66fa978 ┆     ┆ f86a1f8698 ┆ b483032ff1 ┆            │
# │             ┆             ┆            ┆ 180e...    ┆     ┆ 5f         ┆ c7         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630437982  ┆ 2021-08-31  ┆ 13135192   ┆ 0xdc51ca7b ┆ 25  ┆ 0x6cf9aa65 ┆ 0xbebc4478 ┆ 2.2012e6   │
# │             ┆ 23:26:22    ┆            ┆ ee186852c3 ┆     ┆ ebad702853 ┆ 2c7db0a1a6 ┆            │
# │             ┆             ┆            ┆ f8d6809411 ┆     ┆ 6e35339363 ┆ 0cb6fe97d0 ┆            │
# │             ┆             ┆            ┆ 373b3d074a ┆     ┆ 0e2340ca60 ┆ b483032ff1 ┆            │
# │             ┆             ┆            ┆ a67a...    ┆     ┆ 49         ┆ c7         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439358  ┆ 2021-08-31  ┆ 13135296   ┆ 0x76a46d9d ┆ 35  ┆ 0xbebc4478 ┆ 0xd632f226 ┆ 2.4467e6   │
# │             ┆ 23:49:18    ┆            ┆ 2381e6adfc ┆     ┆ 2c7db0a1a6 ┆ 92fac7611d ┆            │
# │             ┆             ┆            ┆ 8c474af8b5 ┆     ┆ 0cb6fe97d0 ┆ 2aa1c0d552 ┆            │
# │             ┆             ┆            ┆ c1500be432 ┆     ┆ b483032ff1 ┆ 930d43caed ┆            │
# │             ┆             ┆            ┆ 67f0...    ┆     ┆ c7         ┆ 3b         ┆            │
# └─────────────┴─────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┘

# %%
# All erc20 mints and burns
erc20_data.emission
# Out:
# shape: (25429, 8)
# ┌─────────────┬─────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┐
# │ timestamp   ┆ date        ┆ block_numb ┆ transactio ┆ log ┆ from       ┆ to         ┆ value      │
# │ ---         ┆ ---         ┆ er         ┆ n_hash     ┆ _in ┆ ---        ┆ ---        ┆ ---        │
# │ u64         ┆ datetime[μs ┆ ---        ┆ ---        ┆ dex ┆ str        ┆ str        ┆ f64        │
# │             ┆ ]           ┆ u64        ┆ str        ┆ --- ┆            ┆            ┆            │
# │             ┆             ┆            ┆            ┆ u64 ┆            ┆            ┆            │
# ╞═════════════╪═════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╡
# │ 1622491237  ┆ 2021-06-01  ┆ 12544147   ┆ 0x95856a3f ┆ 207 ┆ 0xb1cc09d7 ┆ 0x00000000 ┆ 53027.9670 │
# │             ┆ 00:00:37    ┆            ┆ e5a77e9890 ┆     ┆ 3c4bdc572d ┆ 0000000000 ┆ 15         │
# │             ┆             ┆            ┆ 83dd982980 ┆     ┆ c5cf6cef1a ┆ 0000000000 ┆            │
# │             ┆             ┆            ┆ 94ab3089d1 ┆     ┆ 5d0755b3ab ┆ 0000000000 ┆            │
# │             ┆             ┆            ┆ 9940...    ┆     ┆ e1         ┆ 00         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1622492946  ┆ 2021-06-01  ┆ 12544277   ┆ 0xdd64eacb ┆ 28  ┆ 0x00000000 ┆ 0x1187314f ┆ 301112.586 │
# │             ┆ 00:29:06    ┆            ┆ 99904f15ca ┆     ┆ 0000000000 ┆ ba102a5571 ┆            │
# │             ┆             ┆            ┆ f72d23d8fc ┆     ┆ 0000000000 ┆ 2c4467cb85 ┆            │
# │             ┆             ┆            ┆ 07c1560781 ┆     ┆ 0000000000 ┆ b05f8d3712 ┆            │
# │             ┆             ┆            ┆ 38ff...    ┆     ┆ 00         ┆ e8         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1622492973  ┆ 2021-06-01  ┆ 12544279   ┆ 0x40b107c1 ┆ 198 ┆ 0x00000000 ┆ 0x7e29aa45 ┆ 1156.21232 │
# │             ┆ 00:29:33    ┆            ┆ 996a9c7ba7 ┆     ┆ 0000000000 ┆ 8fac18ee1a ┆ 5          │
# │             ┆             ┆            ┆ 78770249e2 ┆     ┆ 0000000000 ┆ 63b5a2e704 ┆            │
# │             ┆             ┆            ┆ ea31d2d3f3 ┆     ┆ 0000000000 ┆ 822dc4ad12 ┆            │
# │             ┆             ┆            ┆ 9069...    ┆     ┆ 00         ┆ 4b         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1622494840  ┆ 2021-06-01  ┆ 12544421   ┆ 0x61842711 ┆ 267 ┆ 0x00000000 ┆ 0xfd3dfb52 ┆ 506.915546 │
# │             ┆ 01:00:40    ┆            ┆ a367a99f98 ┆     ┆ 0000000000 ┆ 4b2da40c8a ┆            │
# │             ┆             ┆            ┆ dc234e65bc ┆     ┆ 0000000000 ┆ 6d703c62be ┆            │
# │             ┆             ┆            ┆ bdc1b9ca01 ┆     ┆ 0000000000 ┆ 36b5d85406 ┆            │
# │             ┆             ┆            ┆ 0464...    ┆     ┆ 00         ┆ 26         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...         ┆ ...         ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630438710  ┆ 2021-08-31  ┆ 13135247   ┆ 0x8dbf116f ┆ 67  ┆ 0x00000000 ┆ 0x9c0da346 ┆ 100000.0   │
# │             ┆ 23:38:30    ┆            ┆ 8c72639526 ┆     ┆ 0000000000 ┆ 7aed02e49f ┆            │
# │             ┆             ┆            ┆ 81b862fdfd ┆     ┆ 0000000000 ┆ e051104efb ┆            │
# │             ┆             ┆            ┆ f4bee8b0a2 ┆     ┆ 0000000000 ┆ 2255c2982c ┆            │
# │             ┆             ┆            ┆ d691...    ┆     ┆ 00         ┆ 61         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439186  ┆ 2021-08-31  ┆ 13135283   ┆ 0x71dd8dd5 ┆ 378 ┆ 0xe913d174 ┆ 0x00000000 ┆ 48847.9531 │
# │             ┆ 23:46:26    ┆            ┆ 5776df29b6 ┆     ┆ 5324208d2e ┆ 0000000000 ┆ 28         │
# │             ┆             ┆            ┆ d5526eb441 ┆     ┆ 473a035509 ┆ 0000000000 ┆            │
# │             ┆             ┆            ┆ 07852f4cd0 ┆     ┆ e9cc781be8 ┆ 0000000000 ┆            │
# │             ┆             ┆            ┆ 7a7f...    ┆     ┆ 9c         ┆ 00         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439464  ┆ 2021-08-31  ┆ 13135304   ┆ 0x0c8bd88d ┆ 218 ┆ 0x00000000 ┆ 0xb66190f6 ┆ 5000.0     │
# │             ┆ 23:51:04    ┆            ┆ 09f3c06ea7 ┆     ┆ 0000000000 ┆ 7ed8f0ca79 ┆            │
# │             ┆             ┆            ┆ bd3731aaad ┆     ┆ 0000000000 ┆ 0ddfe541ee ┆            │
# │             ┆             ┆            ┆ 9862842908 ┆     ┆ 0000000000 ┆ 1bd0da53fe ┆            │
# │             ┆             ┆            ┆ d9ad...    ┆     ┆ 00         ┆ 70         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439926  ┆ 2021-08-31  ┆ 13135339   ┆ 0x1bda116d ┆ 336 ┆ 0x00000000 ┆ 0x65cf8ebc ┆ 80000.0    │
# │             ┆ 23:58:46    ┆            ┆ 02870ecb66 ┆     ┆ 0000000000 ┆ 125aa5e320 ┆            │
# │             ┆             ┆            ┆ 8b871c815c ┆     ┆ 0000000000 ┆ fb8dd5569f ┆            │
# │             ┆             ┆            ┆ 9ed61a51b3 ┆     ┆ 0000000000 ┆ e1b0a86d07 ┆            │
# │             ┆             ┆            ┆ 399b...    ┆     ┆ 00         ┆ 59         ┆            │
# └─────────────┴─────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┘

# %%
# All token volumes by address
erc20_data.volume
# Out:
# shape: (9724, 3)
# ┌────────────────────────────────────────────┬───────────┬───────────────┐
# │ address                                    ┆ volume    ┆ change        │
# │ ---                                        ┆ ---       ┆ ---           │
# │ str                                        ┆ f64       ┆ f64           │
# ╞════════════════════════════════════════════╪═══════════╪═══════════════╡
# │ 0x5d3a536e4d6dbd6114cc1ead35777bab948e3643 ┆ 3.4400e10 ┆ 3.3846e8      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0xbebc44782c7db0a1a60cb6fe97d0b483032ff1c7 ┆ 6.4881e9  ┆ 1.0923e8      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0x55ec3771376b6e1e4ca88d0eea5e42a448f51c7f ┆ 3.7626e9  ┆ -98289.409945 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0x6341c289b2e0795a04223df04b53a77970958723 ┆ 3.7455e9  ┆ -4.1831e8     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...                                        ┆ ...       ┆ ...           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0x2303a26e13ebb95eb0012f25d802f944ac9c0222 ┆ 0.0       ┆ 0.0           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0xd0118b21a632615d899b02e8472e9457dd98062c ┆ 0.0       ┆ 0.0           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0xe3d16e94b76bdfb8e6fa0e9e579601de710f13ae ┆ 0.0       ┆ 0.0           │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0xe41379f11043b9dc32ff9199a246b3a878ac8209 ┆ 0.0       ┆ 0.0           │
# └────────────────────────────────────────────┴───────────┴───────────────┘

# %%
# Historical total supply
erc20_data.total_supply(dates)
# Out:
# shape: (4, 4)
# ┌────────────┬─────────────────────┬──────────────┬──────────────┐
# │ timestamp  ┆ date                ┆ block_number ┆ total_supply │
# │ ---        ┆ ---                 ┆ ---          ┆ ---          │
# │ u64        ┆ datetime[μs]        ┆ u64          ┆ f64          │
# ╞════════════╪═════════════════════╪══════════════╪══════════════╡
# │ 1622491198 ┆ 2021-05-31 23:59:58 ┆ 12544144     ┆ 4.4210e9     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1625083196 ┆ 2021-06-30 23:59:56 ┆ 12737409     ┆ 5.1385e9     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1627761592 ┆ 2021-07-31 23:59:52 ┆ 12935314     ┆ 5.3800e9     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439993 ┆ 2021-08-31 23:59:53 ┆ 13135344     ┆ 5.8493e9     │
# └────────────┴─────────────────────┴──────────────┴──────────────┘

# %%
# Historical balances for addresses
erc20_data.balances(addresses, dates)
# Out:
# shape: (8, 5)
# ┌────────────┬─────────────────────┬──────────────┬─────────────────────────────────────┬──────────┐
# │ timestamp  ┆ date                ┆ block_number ┆ address                             ┆ balance  │
# │ ---        ┆ ---                 ┆ ---          ┆ ---                                 ┆ ---      │
# │ u64        ┆ datetime[μs]        ┆ u64          ┆ str                                 ┆ f64      │
# ╞════════════╪═════════════════════╪══════════════╪═════════════════════════════════════╪══════════╡
# │ 1622491198 ┆ 2021-05-31 23:59:58 ┆ 12544144     ┆ 0x5d3a536e4d6dbd6114cc1ead35777bab9 ┆ 8.1020e8 │
# │            ┆                     ┆              ┆ 48e3643                             ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1622491198 ┆ 2021-05-31 23:59:58 ┆ 12544144     ┆ 0xbebc44782c7db0a1a60cb6fe97d0b4830 ┆ 1.7743e8 │
# │            ┆                     ┆              ┆ 32ff1c7                             ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1625083196 ┆ 2021-06-30 23:59:56 ┆ 12737409     ┆ 0x5d3a536e4d6dbd6114cc1ead35777bab9 ┆ 8.2942e8 │
# │            ┆                     ┆              ┆ 48e3643                             ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1625083196 ┆ 2021-06-30 23:59:56 ┆ 12737409     ┆ 0xbebc44782c7db0a1a60cb6fe97d0b4830 ┆ 2.4975e8 │
# │            ┆                     ┆              ┆ 32ff1c7                             ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1627761592 ┆ 2021-07-31 23:59:52 ┆ 12935314     ┆ 0x5d3a536e4d6dbd6114cc1ead35777bab9 ┆ 1.1784e9 │
# │            ┆                     ┆              ┆ 48e3643                             ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1627761592 ┆ 2021-07-31 23:59:52 ┆ 12935314     ┆ 0xbebc44782c7db0a1a60cb6fe97d0b4830 ┆ 2.5936e8 │
# │            ┆                     ┆              ┆ 32ff1c7                             ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439993 ┆ 2021-08-31 23:59:53 ┆ 13135344     ┆ 0x5d3a536e4d6dbd6114cc1ead35777bab9 ┆ 1.1487e9 │
# │            ┆                     ┆              ┆ 48e3643                             ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439993 ┆ 2021-08-31 23:59:53 ┆ 13135344     ┆ 0xbebc44782c7db0a1a60cb6fe97d0b4830 ┆ 2.8666e8 │
# │            ┆                     ┆              ┆ 32ff1c7                             ┆          │
# └────────────┴─────────────────────┴──────────────┴─────────────────────────────────────┴──────────┘
