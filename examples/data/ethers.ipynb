# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], "../.."))

# %%
from datetime import datetime
from web3cat.data import EtherData

# %%
dates = [datetime(2021, 6, 1), datetime(2021, 7, 1), datetime(2021, 8, 1), datetime(2021, 9, 1)]
addresses = ["0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2", "0xf977814e90da44bfa03b6295a0616a897441acec"]
ether_data = EtherData(min(dates), max(dates))

# %%
# Historical Ether balances for addresses
ether_data.balances(addresses, dates)
# Out:
# Fetching 8 eth balances |████████████████████| 100.0%
# shape: (8, 5)
# ┌────────────┬─────────────────────┬──────────────┬────────────────────────────────┬───────────────┐
# │ timestamp  ┆ date                ┆ block_number ┆ address                        ┆ balance       │
# │ ---        ┆ ---                 ┆ ---          ┆ ---                            ┆ ---           │
# │ u64        ┆ datetime[μs]        ┆ u64          ┆ str                            ┆ f64           │
# ╞════════════╪═════════════════════╪══════════════╪════════════════════════════════╪═══════════════╡
# │ 1622491198 ┆ 2021-05-31 23:59:58 ┆ 12544144     ┆ 0xc02aaa39b223fe8d0a0e5c4f27ea ┆ 6.0283e6      │
# │            ┆                     ┆              ┆ d9083c756cc2                   ┆               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1622491198 ┆ 2021-05-31 23:59:58 ┆ 12544144     ┆ 0xf977814e90da44bfa03b6295a061 ┆ 890939.774346 │
# │            ┆                     ┆              ┆ 6a897441acec                   ┆               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1625083196 ┆ 2021-06-30 23:59:56 ┆ 12737409     ┆ 0xc02aaa39b223fe8d0a0e5c4f27ea ┆ 6.2978e6      │
# │            ┆                     ┆              ┆ d9083c756cc2                   ┆               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1625083196 ┆ 2021-06-30 23:59:56 ┆ 12737409     ┆ 0xf977814e90da44bfa03b6295a061 ┆ 1.3165e6      │
# │            ┆                     ┆              ┆ 6a897441acec                   ┆               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1627761592 ┆ 2021-07-31 23:59:52 ┆ 12935314     ┆ 0xc02aaa39b223fe8d0a0e5c4f27ea ┆ 6.9281e6      │
# │            ┆                     ┆              ┆ d9083c756cc2                   ┆               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1627761592 ┆ 2021-07-31 23:59:52 ┆ 12935314     ┆ 0xf977814e90da44bfa03b6295a061 ┆ 519929.208384 │
# │            ┆                     ┆              ┆ 6a897441acec                   ┆               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439993 ┆ 2021-08-31 23:59:53 ┆ 13135344     ┆ 0xc02aaa39b223fe8d0a0e5c4f27ea ┆ 7.0331e6      │
# │            ┆                     ┆              ┆ d9083c756cc2                   ┆               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1630439993 ┆ 2021-08-31 23:59:53 ┆ 13135344     ┆ 0xf977814e90da44bfa03b6295a061 ┆ 500008.151647 │
# │            ┆                     ┆              ┆ 6a897441acec                   ┆               │
# └────────────┴─────────────────────┴──────────────┴────────────────────────────────┴───────────────┘
