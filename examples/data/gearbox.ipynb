# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], "../.."))

# %%
from datetime import datetime
from web3cat.data import GearboxData

# %%
data = GearboxData(start = datetime(2022, 1, 1), end = datetime(2022, 12, 12))

# List all liquidations
data.liquidations
# Out:
# Resolving 1 block numbers |████████████████████| 100.0%
# Resolving 1 block numbers |████████████████████| 100.0%
# Fetching LiquidateCreditAccount@0xf6f4...854F (13915000 - 16164000) |████████████████████| 100.0%
# Fetching LiquidateCreditAccount@0x61fb...84aa (13915000 - 16164000) |████████████████████| 100.0%
# Fetching LiquidateCreditAccount@0xC591...a304 (13915000 - 16164000) |████████████████████| 100.0%
# Fetching LiquidateCreditAccount@0xAfae...3243 (13915000 - 16164000) |████████████████████| 100.0%
# Fetching LiquidateCreditAccount@0x04d6...2546 (13915000 - 16164000) |████████████████████| 100.0%
# Resolving 4 block numbers |████████████████████| 100.0%
# shape: (3, 9)
# ┌─────────┬──────────┬────────────┬────────────┬─────┬──────────┬──────────┬──────────┬────────────┐
# │ timesta ┆ date     ┆ block_numb ┆ transactio ┆ ... ┆ borrower ┆ liquidat ┆ to       ┆ remaining_ │
# │ mp      ┆ ---      ┆ er         ┆ n_hash     ┆     ┆ ---      ┆ or       ┆ ---      ┆ funds      │
# │ ---     ┆ datetime ┆ ---        ┆ ---        ┆     ┆ str      ┆ ---      ┆ str      ┆ ---        │
# │ u64     ┆ [μs]     ┆ u64        ┆ str        ┆     ┆          ┆ str      ┆          ┆ f64        │
# ╞═════════╪══════════╪════════════╪════════════╪═════╪══════════╪══════════╪══════════╪════════════╡
# │ 1667412 ┆ 2022-11- ┆ 15884037   ┆ 0xa6705997 ┆ ... ┆ 0x39c78c ┆ 0x6c6b87 ┆ 0x6c6b87 ┆ 11.081476  │
# │ 639     ┆ 02       ┆            ┆ b63e0d8737 ┆     ┆ e4fbd597 ┆ d44d239b ┆ d44d239b ┆            │
# │         ┆ 22:10:39 ┆            ┆ 6cd5fe5c49 ┆     ┆ 22f48a32 ┆ 3750bf9b ┆ 3750bf9b ┆            │
# │         ┆          ┆            ┆ b4f5bf4ecf ┆     ┆ 71fe11f9 ┆ adce26a9 ┆ adce26a9 ┆            │
# │         ┆          ┆            ┆ df3b...    ┆     ┆ ac5f933b ┆ a0a3d236 ┆ a0a3d236 ┆            │
# │         ┆          ┆            ┆            ┆     ┆ a0       ┆ 4e       ┆ 4e       ┆            │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1667923 ┆ 2022-11- ┆ 15926405   ┆ 0x8e5e1052 ┆ ... ┆ 0xdfe201 ┆ 0xfa1232 ┆ 0xfa1232 ┆ 13.380568  │
# │ 631     ┆ 08       ┆            ┆ cc38df27d3 ┆     ┆ cedc41f9 ┆ 3eb95256 ┆ 3eb95256 ┆            │
# │         ┆ 20:07:11 ┆            ┆ 36f91f6da9 ┆     ┆ 70d43f95 ┆ 8ca05085 ┆ 8ca05085 ┆            │
# │         ┆          ┆            ┆ c6fc15578d ┆     ┆ 674d6b4b ┆ b9da9f66 ┆ b9da9f66 ┆            │
# │         ┆          ┆            ┆ ead8...    ┆     ┆ e02de784 ┆ a4458dee ┆ a4458dee ┆            │
# │         ┆          ┆            ┆            ┆     ┆ dd       ┆ 27       ┆ 27       ┆            │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1667923 ┆ 2022-11- ┆ 15926406   ┆ 0x2d9244ab ┆ ... ┆ 0x69c509 ┆ 0x0e1139 ┆ 0x0e1139 ┆ 27.491282  │
# │ 643     ┆ 08       ┆            ┆ e624c4edd3 ┆     ┆ e9765c49 ┆ 04cb1d53 ┆ 04cb1d53 ┆            │
# │         ┆ 20:07:23 ┆            ┆ ec78a9db73 ┆     ┆ cc6b9b45 ┆ cabb3249 ┆ cabb3249 ┆            │
# │         ┆          ┆            ┆ 9342078463 ┆     ┆ 68b90aa4 ┆ 27dffae2 ┆ 27dffae2 ┆            │
# │         ┆          ┆            ┆ e0bb...    ┆     ┆ 7b89f499 ┆ f8f67051 ┆ f8f67051 ┆            │
# │         ┆          ┆            ┆            ┆     ┆ 2f       ┆ 11       ┆ 11       ┆            │
# └─────────┴──────────┴────────────┴────────────┴─────┴──────────┴──────────┴──────────┴────────────┘
