# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], "../.."))

# %%
from datetime import datetime
from data import PortfolioData

# %%
addresses = [
    "0x78605Df79524164911C144801f41e9811B7DB73D",
    "0xBF72Da2Bd84c5170618Fbe5914B0ECA9638d5eb5",
    "0x8EB8a3b98659Cce290402893d0123abb75E3ab28"
]
tokens = ["USDC", "WETH", "ETH", "WBTC"]
base_tokens = ["USDC", "WETH"]
portfolio_data = PortfolioData(
    tokens=tokens, 
    base_tokens=base_tokens, 
    addresses = addresses, 
    start = datetime(2022, 6, 1), 
    end = datetime(2022, 9, 1), 
    numpoints = 4
)

# %%
# Portfolio value in USDC by address for USDC, WETH, ETH and WBTC holdings
portfolio_data.breakdown_by_address("USDC")
# Out:
# shape: (4, 7)
# ┌────────────┬─────────────────────┬──────────┬──────────┬──────────┬──────────┬──────────┐
# │ timestamp  ┆ date                ┆ block_nu ┆ 0x78605d ┆ 0x8eb8a3 ┆ 0xbf72da ┆ total    │
# │ ---        ┆ ---                 ┆ mber     ┆ f7952416 ┆ b98659cc ┆ 2bd84c51 ┆ ---      │
# │ u64        ┆ datetime[μs]        ┆ ---      ┆ 4911c144 ┆ e2904028 ┆ 70618fbe ┆ f64      │
# │            ┆                     ┆ u64      ┆ 801f41e9 ┆ 93d0123a ┆ 5914b0ec ┆          │
# │            ┆                     ┆          ┆ 811b7db7 ┆ bb75e3ab ┆ a9638d5e ┆          │
# │            ┆                     ┆          ┆ 3d       ┆ 28       ┆ b5       ┆          │
# │            ┆                     ┆          ┆ ---      ┆ ---      ┆ ---      ┆          │
# │            ┆                     ┆          ┆ f64      ┆ f64      ┆ f64      ┆          │
# ╞════════════╪═════════════════════╪══════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1654027190 ┆ 2022-05-31 23:59:50 ┆ 14880658 ┆ 5.5729e8 ┆ 0.0      ┆ 8.2152e8 ┆ 1.3788e9 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1656856163 ┆ 2022-07-03 17:49:23 ┆ 15069970 ┆ 4.2180e8 ┆ 0.0      ┆ 1.0988e9 ┆ 1.5206e9 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1659391946 ┆ 2022-08-02 02:12:26 ┆ 15259282 ┆ 6.0541e8 ┆ 8.8980e8 ┆ 7.7663e8 ┆ 2.2718e9 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1661975991 ┆ 2022-08-31 23:59:51 ┆ 15448594 ┆ 6.4580e8 ┆ 7.2251e8 ┆ 6.8033e8 ┆ 2.0486e9 │
# └────────────┴─────────────────────┴──────────┴──────────┴──────────┴──────────┴──────────┘

# %%
# Portfolio value in WETH by address for USDC, WETH, ETH and WBTC holdings
portfolio_data.breakdown_by_address("WETH")
# Out:
# shape: (4, 7)
# ┌────────────┬──────────────┬────────────┬────────────┬──────────────┬──────────────┬──────────────┐
# │ timestamp  ┆ date         ┆ block_numb ┆ 0x78605df7 ┆ 0x8eb8a3b986 ┆ 0xbf72da2bd8 ┆ total        │
# │ ---        ┆ ---          ┆ er         ┆ 9524164911 ┆ 59cce2904028 ┆ 4c5170618fbe ┆ ---          │
# │ u64        ┆ datetime[μs] ┆ ---        ┆ c144801f41 ┆ 93d0123abb75 ┆ 5914b0eca963 ┆ f64          │
# │            ┆              ┆ u64        ┆ e9811b7db7 ┆ e3ab28       ┆ 8d5eb5       ┆              │
# │            ┆              ┆            ┆ 3d         ┆ ---          ┆ ---          ┆              │
# │            ┆              ┆            ┆ ---        ┆ f64          ┆ f64          ┆              │
# │            ┆              ┆            ┆ f64        ┆              ┆              ┆              │
# ╞════════════╪══════════════╪════════════╪════════════╪══════════════╪══════════════╪══════════════╡
# │ 1654027190 ┆ 2022-05-31   ┆ 14880658   ┆ 288070.049 ┆ 0.0          ┆ 424652.98389 ┆ 712723.03347 │
# │            ┆ 23:59:50     ┆            ┆ 578        ┆              ┆ 4            ┆ 2            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1656856163 ┆ 2022-07-03   ┆ 15069970   ┆ 402296.533 ┆ 0.0          ┆ 1.0480e6     ┆ 1.4502e6     │
# │            ┆ 17:49:23     ┆            ┆ 206        ┆              ┆              ┆              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1659391946 ┆ 2022-08-02   ┆ 15259282   ┆ 374944.692 ┆ 551071.13967 ┆ 480983.44841 ┆ 1.4070e6     │
# │            ┆ 02:12:26     ┆            ┆ 021        ┆ 8            ┆ 3            ┆              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1661975991 ┆ 2022-08-31   ┆ 15448594   ┆ 409049.796 ┆ 457636.61380 ┆ 430918.87394 ┆ 1.2976e6     │
# │            ┆ 23:59:51     ┆            ┆ 585        ┆ 7            ┆ 6            ┆              │
# └────────────┴──────────────┴────────────┴────────────┴──────────────┴──────────────┴──────────────┘

# %%
# Portfolio value in USDC by token for USDC, WETH, ETH and WBTC holdings
portfolio_data.breakdown_by_token("USDC")
# Out:
# shape: (4, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬────────────┬──────────┐
# │ timestamp  ┆ date       ┆ block_numb ┆ USDC      ┆ WETH      ┆ WBTC      ┆ ETH (USDC) ┆ total    │
# │ ---        ┆ ---        ┆ er         ┆ (USDC)    ┆ (USDC)    ┆ (USDC)    ┆ ---        ┆ ---      │
# │ u64        ┆ datetime[μ ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ f64        ┆ f64      │
# │            ┆ s]         ┆ u64        ┆ f64       ┆ f64       ┆ f64       ┆            ┆          │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪════════════╪══════════╡
# │ 1654027190 ┆ 2022-05-31 ┆ 14880658   ┆ 1.6892831 ┆ 0.0       ┆ 8.2152e8  ┆ 3.8836e8   ┆ 1.3788e9 │
# │            ┆ 23:59:50   ┆            ┆ 7e8       ┆           ┆           ┆            ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1656856163 ┆ 2022-07-03 ┆ 15069970   ┆ 1.9063938 ┆ 0.0       ┆ 1.0988e9  ┆ 2.3116e8   ┆ 1.5206e9 │
# │            ┆ 17:49:23   ┆            ┆ 4e8       ┆           ┆           ┆            ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1659391946 ┆ 2022-08-02 ┆ 15259282   ┆ 6.1765e8  ┆ 2.5548e8  ┆ 1.0005e9  ┆ 3.9825e8   ┆ 2.2718e9 │
# │            ┆ 02:12:26   ┆            ┆           ┆           ┆           ┆            ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 1661975991 ┆ 2022-08-31 ┆ 15448594   ┆ 6.1091e8  ┆ 1.9726e8  ┆ 8.3276e8  ┆ 4.0771e8   ┆ 2.0486e9 │
# │            ┆ 23:59:51   ┆            ┆           ┆           ┆           ┆            ┆          │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴────────────┴──────────┘

# %%
# Portfolio value in WETH by token for USDC, WETH, ETH and WBTC holdings
portfolio_data.breakdown_by_token("WETH")
# Out:
# shape: (4, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬──────────┬────────────┐
# │ timestamp  ┆ date       ┆ block_numb ┆ USDC      ┆ WETH      ┆ WBTC      ┆ ETH      ┆ total      │
# │ ---        ┆ ---        ┆ er         ┆ (WETH)    ┆ (WETH)    ┆ (WETH)    ┆ (WETH)   ┆ ---        │
# │ u64        ┆ datetime[μ ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---      ┆ f64        │
# │            ┆ s]         ┆ u64        ┆ f64       ┆ f64       ┆ f64       ┆ f64      ┆            │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪══════════╪════════════╡
# │ 1654027190 ┆ 2022-05-31 ┆ 14880658   ┆ 87321.111 ┆ 0.0       ┆ 424652.98 ┆ 200748.9 ┆ 712723.033 │
# │            ┆ 23:59:50   ┆            ┆ 105       ┆           ┆ 3894      ┆ 38473    ┆ 472        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1656856163 ┆ 2022-07-03 ┆ 15069970   ┆ 181822.84 ┆ 0.0       ┆ 1.0480e6  ┆ 220473.6 ┆ 1.4502e6   │
# │            ┆ 17:49:23   ┆            ┆ 4733      ┆           ┆           ┆ 88473    ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1659391946 ┆ 2022-08-02 ┆ 15259282   ┆ 382521.87 ┆ 158222.84 ┆ 619607.49 ┆ 246647.0 ┆ 1.4070e6   │
# │            ┆ 02:12:26   ┆            ┆ 0306      ┆ 5577      ┆ 2838      ┆ 71392    ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1661975991 ┆ 2022-08-31 ┆ 15448594   ┆ 386948.38 ┆ 124942.16 ┆ 527473.17 ┆ 258241.5 ┆ 1.2976e6   │
# │            ┆ 23:59:51   ┆            ┆ 2963      ┆ 0947      ┆ 3578      ┆ 6685     ┆            │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴──────────┴────────────┘

# %%
# Balance and price data
portfolio_data.balances_and_prices
# Out:
# shape: (12, 16)
# ┌─────────┬───────────┬────────────┬───────────┬─────┬───────────┬───────────┬──────────┬──────────┐
# │ timesta ┆ date      ┆ block_numb ┆ address   ┆ ... ┆ WBTC /    ┆ WBTC /    ┆ ETH /    ┆ ETH /    │
# │ mp      ┆ ---       ┆ er         ┆ ---       ┆     ┆ USDC      ┆ WETH      ┆ USDC     ┆ WETH     │
# │ ---     ┆ datetime[ ┆ ---        ┆ str       ┆     ┆ ---       ┆ ---       ┆ ---      ┆ ---      │
# │ u64     ┆ μs]       ┆ u64        ┆           ┆     ┆ f64       ┆ f64       ┆ f64      ┆ f64      │
# ╞═════════╪═══════════╪════════════╪═══════════╪═════╪═══════════╪═══════════╪══════════╪══════════╡
# │ 1654027 ┆ 2022-05-3 ┆ 14880658   ┆ 0x78605df ┆ ... ┆ 31623.487 ┆ 16.346567 ┆ 1934.564 ┆ 1.0      │
# │ 190     ┆ 1         ┆            ┆ 795241649 ┆     ┆ 383       ┆           ┆ 447      ┆          │
# │         ┆ 23:59:50  ┆            ┆ 11c144801 ┆     ┆           ┆           ┆          ┆          │
# │         ┆           ┆            ┆ f41e9811b ┆     ┆           ┆           ┆          ┆          │
# │         ┆           ┆            ┆ 7db73d    ┆     ┆           ┆           ┆          ┆          │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 