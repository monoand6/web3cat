# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], "../.."))

# %%
from datetime import datetime
from bokeh.io import output_notebook
from view import View


output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
v1 = View(token="DAI", start=datetime(2022, 6, 1), end = datetime(2022, 10, 30)) \
    .total_supply() \
    .balance(["0x5d3a536E4D6DbD6114cc1Ead35777bAB948E3643", "0x467194771dAe2967Aef3ECbEDD3Bf9a310C76C65"])
v1.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 2
#       1 v1 = View(token="DAI", start=datetime(2022, 6, 1), end = datetime(2022, 10, 30)) \
# ----> 2     .total_supply() \
#       3     .balance(["0x5d3a536E4D6DbD6114cc1Ead35777bAB948E3643", "0x467194771dAe2967Aef3ECbEDD3Bf9a310C76C65"])
#       4 v1.show()
#
# File ~/dev/web3cat/examples/view/../../view/view.py:129, in View.total_supply(self, token, start, end, numpoints)
#     112 """
#     113 Historical total supply of the ERC20 tokens
#     114
#    (...)
#     119     numpoints: number of points in between
#     120 """
#     121 args = self._build_wireframe_args(
#     122     {
#     123         "token": token,
#    (...)
#     127     }
#     128 )
# --> 129 args["token"] = self._erc20_metas_service.get(args["token"])
#     130 self._wireframes.append(TotalSupplyWireframe(**args))
#     131 return self
#
# File ~/dev/web3cat/examples/view/../../fetcher/erc20_metas/service.py:96, in ERC20MetasService.get(self, token)
#      82 """
#      83 Get metadata by token symbol or token address.
#      84
#    (...)
#      93     An instance of :class:`ERC20Meta` or ``None`` if not found.
#      94 """
#      95 token = token.lower()
# ---> 96 cached_token = self._get_from_cache(token)
#      97 if not cached_token:
#      98     cached_token = self._erc20_metas_repo.find(token)
#
# File ~/dev/web3cat/examples/view/../../fetcher/erc20_metas/service.py:130, in ERC20MetasService._get_from_cache(self, token)
#     128 def _get_from_cache(self, token: str) -> ERC20Meta | None:
#     129     token = token.lower()
# --> 130     chain_id = str(self.chain_id)
#     131     if not chain_id in self._cache:
#     132         return None
#
# File /opt/homebrew/Cellar/python@3.10/3.10.6_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/dev/web3cat/examples/view/../../fetcher/core.py:120, in Core.chain_id(self)
#     116 """
#     117 Chain id for the current web3 connection
#     118 """
#     119 if not self.rpc:
# --> 120     return self.w3.eth.chain_id
#     122 if not self.rpc in chain_id_cache:
#     123     chain_id_cache[self.rpc] = self.w3.eth.chain_id
#
# File /opt/homebrew/Cellar/python@3.10/3.10.6_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/functools.py:981, in cached_property.__get__(self, instance, owner)
#     979 val = cache.get(self.attrname, _NOT_FOUND)
#     980 if val is _NOT_FOUND:
# --> 981     val = self.func(instance)
#     982     try:
#     983         cache[self.attrname] = val
#
# File ~/dev/web3cat/examples/view/../../fetcher/core.py:147, in Core.w3(self)
#     144     return self._w3
#     146 if self.rpc is None:
# --> 147     raise ValueError(
#     148         "Ethereum RPC is not set. "
#     149         "Use `WEB3_PROVIDER_URI` env variable or pass rpc explicitly"
#     150     )
#     152 if not self.rpc in web3_cache:
#     153     web3_cache[self.rpc] = Web3(Web3.HTTPProvider(self.rpc))
#
# ValueError: Ethereum RPC is not set. Use `WEB3_PROVIDER_URI` env variable or pass rpc explicitly

# %%
v2 = View(start=datetime(2022, 6, 1), end = datetime(2022, 10, 30)) \
    .total_supply(token="USDC") \
    .total_supply(token="DAI")
v2.show()

# %%
v3 = View(token="WBTC", start=datetime(2022, 6, 1), end = datetime(2022, 10, 30)) \
    .total_supply() \
    .chainlink_prices(token_base = "USDC")
v3.show()

# %%
v4 = View(token="ETH", start=datetime(2022, 6, 1), end = datetime(2022, 10, 30)) \
    .balance(["0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2", "0xf977814e90da44bfa03b6295a0616a897441acec"])
v4.show()

# %%
addresses = [
    "0x78605Df79524164911C144801f41e9811B7DB73D",
    "0xBF72Da2Bd84c5170618Fbe5914B0ECA9638d5eb5",
    "0x8EB8a3b98659Cce290402893d0123abb75E3ab28"
]
tokens = ["USDC", "WETH", "ETH", "WBTC"]
base_tokens = ["USDC", "WETH"]

v5 = View().portfolio_by_token(
    addresses = addresses, 
    tokens = tokens, 
    base_token = "USDC", 
    start=datetime(2022, 10, 1), 
    end=datetime(2022, 10, 30), 
    numpoints=100
)
v5.show()

v6 = View().portfolio_by_address(
    addresses = addresses, 
    tokens = tokens, 
    base_token = "USDC", 
    start=datetime(2022, 10, 1), 
    end=datetime(2022, 10, 30), 
    numpoints=100
)
v6.show()

# %%
v6.get_data(0).breakdown_by_token("USDC")
